# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "cnn1_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn1_base',
#  'time': '2022-10-13 20:29:25.851562',
#  'type': 'train',
#  'Accuracy': [0.96556,
#   0.97862,
#   0.94016,
#   0.92224,
#   0.94572,
#   0.9393,
#   0.9642,
#   0.96818,
#   0.97694,
#   0.97236],
#  'Classification Error': [0.03444,
#   0.02138,
#   0.05984,
#   0.07776,
#   0.05428,
#   0.0607,
#   0.0358,
#   0.03182,
#   0.02306,
#   0.02764],
#  'TP': [4258, 4466, 3597, 3110, 3817, 2955, 4115, 4167, 4542, 4305],
#  'FP': [980, 535, 1589, 1998, 1531, 990, 905, 758, 695, 687],
#  'TN': [44020, 44465, 43411, 43002, 43469, 44010, 44095, 44242, 44305, 44313],
#  'FN': [742, 534, 1403, 1890, 1183, 2045, 885, 833, 458, 695],
#  'Precision': [0.812905689194349,
#   0.8930213957208558,
#   0.6935981488623216,
#   0.6088488645262333,
#   0.7137247569184741,
#   0.7490494296577946,
#   0.8197211155378487,
#   0.8460913705583757,
#   0.8672904334542677,
#   0.8623798076923077],
#  'Recall': [0.8516,
#   0.8932,
#   0.7194,
#   0.622,
#   0.7634,
#   0.591,
#   0.823,
#   0.8334,
#   0.9084,
#   0.861],
#  'Specificity': [0.9782222222222222,
#   0.9881111111111112,
#   0.9646888888888889,
#   0.9556,
#   0.9659777777777778,
#   0.978,
#   0.9798888888888889,
#   0.9831555555555556,
#   0.9845555555555555,
#   0.9847333333333333],
#  'F1-Score': [0.83180308654034,
#   0.8931106889311068,
#   0.7062634989200864,
#   0.6153541749109616,
#   0.7377270970235794,
#   0.6607043040804919,
#   0.8213572854291418,
#   0.8396977329974813,
#   0.887369346488229,
#   0.861689351481185],
#  'confusion_matrix': [[4258, 62, 226, 120, 123, 66, 34, 66, 188, 95],
#   [58, 4466, 21, 25, 14, 16, 21, 20, 72, 288],
#   [164, 11, 3597, 357, 359, 270, 254, 116, 27, 31],
#   [58, 25, 290, 3110, 185, 946, 230, 172, 34, 58],
#   [58, 13, 381, 290, 3817, 293, 198, 239, 25, 34],
#   [19, 9, 142, 533, 77, 2955, 50, 136, 9, 15],
#   [19, 29, 185, 294, 163, 149, 4115, 32, 14, 20],
#   [17, 13, 80, 142, 205, 220, 28, 4167, 11, 42],
#   [242, 96, 50, 77, 29, 46, 31, 12, 4542, 112],
#   [107, 276, 28, 52, 28, 39, 39, 40, 78, 4305]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.957328}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9573280000000001
# Mean Classification Error 0.042672
# Mean Precision 0.7866631012122828
# Mean Recall 0.78664
# Mean Specificity 0.9762933333333332
# Mean F1-Score 0.7855076566802602

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn1_base',
#  'time': '2022-10-13 20:29:26.705107',
#  'type': 'test',
#  'Accuracy': [0.9323,
#   0.9526,
#   0.9083,
#   0.8906,
#   0.916,
#   0.9116,
#   0.9422,
#   0.9425,
#   0.9489,
#   0.9408],
#  'Classification Error': [0.0677,
#   0.0474,
#   0.0917,
#   0.1094,
#   0.084,
#   0.0884,
#   0.0578,
#   0.0575,
#   0.0511,
#   0.0592],
#  'TP': [690, 773, 530, 463, 608, 461, 741, 703, 769, 691],
#  'FP': [367, 247, 447, 557, 448, 345, 319, 278, 280, 283],
#  'TN': [8633, 8753, 8553, 8443, 8552, 8655, 8681, 8722, 8720, 8717],
#  'FN': [310, 227, 470, 537, 392, 539, 259, 297, 231, 309],
#  'Precision': [0.6527909176915799,
#   0.7578431372549019,
#   0.5424769703172978,
#   0.453921568627451,
#   0.5757575757575758,
#   0.5719602977667494,
#   0.6990566037735849,
#   0.7166156982670744,
#   0.7330791229742613,
#   0.7094455852156057],
#  'Recall': [0.69,
#   0.773,
#   0.53,
#   0.463,
#   0.608,
#   0.461,
#   0.741,
#   0.703,
#   0.769,
#   0.691],
#  'Specificity': [0.9592222222222222,
#   0.9725555555555555,
#   0.9503333333333334,
#   0.9381111111111111,
#   0.9502222222222222,
#   0.9616666666666667,
#   0.9645555555555556,
#   0.9691111111111111,
#   0.9688888888888889,
#   0.9685555555555555],
#  'F1-Score': [0.6708799222168205,
#   0.7653465346534652,
#   0.5361659079413252,
#   0.45841584158415843,
#   0.5914396887159533,
#   0.5105204872646734,
#   0.7194174757281553,
#   0.7097425542655225,
#   0.7506100536847244,
#   0.7001013171225936],
#  'confusion_matrix': [[690, 29, 76, 39, 38, 18, 15, 21, 83, 48],
#   [30, 773, 12, 11, 6, 11, 7, 4, 50, 116],
#   [51, 9, 530, 85, 95, 70, 62, 42, 20, 13],
#   [21, 17, 73, 463, 63, 248, 62, 46, 7, 20],
#   [27, 11, 104, 78, 608, 68, 51, 82, 9, 18],
#   [5, 4, 69, 148, 25, 461, 24, 57, 1, 12],
#   [11, 14, 70, 75, 64, 45, 741, 19, 10, 11],
#   [10, 4, 35, 48, 81, 55, 16, 703, 7, 22],
#   [107, 35, 20, 21, 16, 12, 10, 10, 769, 49],
#   [48, 104, 11, 32, 4, 12, 12, 16, 44, 691]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.92858}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9285799999999998
# Mean Classification Error 0.07142000000000001
# Mean Precision 0.6412947477646082
# Mean Recall 0.6429
# Mean Specificity 0.9603222222222223
# Mean F1-Score 0.6412639783177392
