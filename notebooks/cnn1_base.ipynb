# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "cnn1_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn1_base',
#  'time': '2022-10-13 20:02:04.326452',
#  'type': 'train',
#  'Accuracy': [0.94768,
#   0.94802,
#   0.9268,
#   0.89496,
#   0.92308,
#   0.91744,
#   0.94152,
#   0.9522,
#   0.95978,
#   0.93172],
#  'Classification Error': [0.05232,
#   0.05198,
#   0.0732,
#   0.10504,
#   0.07692,
#   0.08256,
#   0.05848,
#   0.0478,
#   0.04022,
#   0.06828],
#  'TP': [3376, 4176, 2292, 2834, 3069, 2458, 3962, 3285, 4035, 4093],
#  'FP': [992, 1775, 952, 3086, 1915, 1586, 1886, 675, 1046, 2507],
#  'TN': [44008, 43225, 44048, 41914, 43085, 43414, 43114, 44325, 43954, 42493],
#  'FN': [1624, 824, 2708, 2166, 1931, 2542, 1038, 1715, 965, 907],
#  'Precision': [0.7728937728937729,
#   0.7017308015459587,
#   0.7065351418002466,
#   0.47871621621621624,
#   0.6157704654895666,
#   0.6078140454995055,
#   0.6774965800273598,
#   0.8295454545454546,
#   0.7941350127927573,
#   0.6201515151515151],
#  'Recall': [0.6752,
#   0.8352,
#   0.4584,
#   0.5668,
#   0.6138,
#   0.4916,
#   0.7924,
#   0.657,
#   0.807,
#   0.8186],
#  'Specificity': [0.9779555555555556,
#   0.9605555555555556,
#   0.9788444444444444,
#   0.9314222222222223,
#   0.9574444444444444,
#   0.9647555555555556,
#   0.9580888888888889,
#   0.985,
#   0.9767555555555556,
#   0.9442888888888888],
#  'F1-Score': [0.7207514944491887,
#   0.7626700757921651,
#   0.5560407569141194,
#   0.5190476190476191,
#   0.6147836538461537,
#   0.5435647943387881,
#   0.7304572271386431,
#   0.7332589285714286,
#   0.8005158218430712,
#   0.7056896551724138],
#  'confusion_matrix': [[3376, 36, 341, 87, 143, 47, 39, 66, 176, 57],
#   [290, 4176, 108, 110, 97, 73, 109, 75, 328, 585],
#   [136, 9, 2292, 172, 231, 157, 107, 93, 28, 19],
#   [112, 23, 499, 2834, 353, 1327, 332, 311, 70, 59],
#   [101, 17, 598, 244, 3069, 299, 181, 427, 32, 16],
#   [30, 11, 292, 608, 224, 2458, 76, 315, 6, 24],
#   [66, 47, 475, 498, 422, 225, 3962, 75, 33, 45],
#   [26, 11, 86, 96, 232, 183, 16, 3285, 7, 18],
#   [472, 93, 119, 93, 78, 47, 39, 21, 4035, 84],
#   [391, 577, 190, 258, 151, 184, 139, 332, 285, 4093]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.93432}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9343200000000002
# Mean Classification Error 0.06568
# Mean Precision 0.6804789005962353
# Mean Recall 0.6716000000000001
# Mean Specificity 0.9635111111111112
# Mean F1-Score 0.668678002711359

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn1_base',
#  'time': '2022-10-13 20:02:05.146993',
#  'type': 'test',
#  'Accuracy': [0.9413,
#   0.9376,
#   0.9165,
#   0.8789,
#   0.913,
#   0.9104,
#   0.9327,
#   0.9392,
#   0.9474,
#   0.9192],
#  'Classification Error': [0.0587,
#   0.0624,
#   0.0835,
#   0.1211,
#   0.087,
#   0.0896,
#   0.0673,
#   0.0608,
#   0.0526,
#   0.0808],
#  'TP': [657, 779, 394, 494, 551, 462, 758, 581, 739, 766],
#  'FP': [244, 403, 229, 705, 421, 358, 431, 189, 265, 574],
#  'TN': [8756, 8597, 8771, 8295, 8579, 8642, 8569, 8811, 8735, 8426],
#  'FN': [343, 221, 606, 506, 449, 538, 242, 419, 261, 234],
#  'Precision': [0.7291897891231964,
#   0.6590524534686971,
#   0.6324237560192616,
#   0.41201000834028356,
#   0.5668724279835391,
#   0.5634146341463414,
#   0.6375105130361648,
#   0.7545454545454545,
#   0.7360557768924303,
#   0.5716417910447761],
#  'Recall': [0.657,
#   0.779,
#   0.394,
#   0.494,
#   0.551,
#   0.462,
#   0.758,
#   0.581,
#   0.739,
#   0.766],
#  'Specificity': [0.9728888888888889,
#   0.9552222222222222,
#   0.9745555555555555,
#   0.9216666666666666,
#   0.9532222222222222,
#   0.9602222222222222,
#   0.9521111111111111,
#   0.979,
#   0.9705555555555555,
#   0.9362222222222222],
#  'F1-Score': [0.6912151499210942,
#   0.7140238313473877,
#   0.4855206407886629,
#   0.44929513415188727,
#   0.5588235294117648,
#   0.5076923076923077,
#   0.6925536774783005,
#   0.656497175141243,
#   0.7375249500998005,
#   0.6547008547008548],
#  'confusion_matrix': [[657, 4, 80, 19, 27, 15, 5, 19, 57, 18],
#   [58, 779, 24, 27, 19, 16, 21, 19, 88, 131],
#   [23, 4, 394, 49, 53, 31, 27, 27, 8, 7],
#   [26, 9, 112, 494, 91, 261, 88, 88, 15, 15],
#   [21, 0, 133, 62, 551, 64, 37, 85, 11, 8],
#   [4, 4, 70, 133, 49, 462, 16, 72, 3, 7],
#   [15, 8, 98, 109, 109, 47, 758, 22, 8, 15],
#   [2, 2, 27, 28, 61, 51, 6, 581, 5, 7],
#   [112, 29, 31, 22, 21, 12, 7, 5, 739, 26],
#   [82, 161, 31, 57, 19, 41, 35, 82, 66, 766]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.92362}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.92362
# Mean Classification Error 0.07637999999999999
# Mean Precision 0.6262716604600145
# Mean Recall 0.6181
# Mean Specificity 0.9575666666666667
# Mean F1-Score 0.6147847250733303
