# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np
plt.style.use('ggplot')

# %%
results_dir ="../results"
report = "cnn1_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn1_base',
#  'time': '2022-10-14 03:42:45.062993',
#  'type': 'train',
#  'Accuracy': [0.99934,
#   0.9992,
#   0.99866,
#   0.99886,
#   0.99854,
#   0.99866,
#   0.99894,
#   0.99882,
#   0.99946,
#   0.99844],
#  'Classification Error': [0.00066,
#   0.0008,
#   0.00134,
#   0.00114,
#   0.00146,
#   0.00134,
#   0.00106,
#   0.00118,
#   0.00054,
#   0.00156],
#  'TP': [4984, 4964, 4936, 4990, 4967, 4957, 4950, 4998, 4983, 4994],
#  'FP': [17, 4, 3, 47, 40, 24, 3, 57, 10, 72],
#  'TN': [44983, 44996, 44997, 44953, 44960, 44976, 44997, 44943, 44990, 44928],
#  'FN': [16, 36, 64, 10, 33, 43, 50, 2, 17, 6],
#  'Precision': [0.9966006798640272,
#   0.999194847020934,
#   0.999392589593035,
#   0.9906690490371253,
#   0.9920111843419213,
#   0.9951816904236097,
#   0.9993943064809206,
#   0.9887240356083086,
#   0.9979971960745043,
#   0.9857876036320569],
#  'Recall': [0.9968,
#   0.9928,
#   0.9872,
#   0.998,
#   0.9934,
#   0.9914,
#   0.99,
#   0.9996,
#   0.9966,
#   0.9988],
#  'Specificity': [0.9996222222222222,
#   0.9999111111111111,
#   0.9999333333333333,
#   0.9989555555555556,
#   0.9991111111111111,
#   0.9994666666666666,
#   0.9999333333333333,
#   0.9987333333333334,
#   0.9997777777777778,
#   0.9984],
#  'F1-Score': [0.9967003299670034,
#   0.9959871589085073,
#   0.9932588791628936,
#   0.9943210122546579,
#   0.992705106425502,
#   0.9932872457669573,
#   0.9946749723701398,
#   0.9941322725012431,
#   0.9972981086760733,
#   0.9922511424597655],
#  'confusion_matrix': [[4984, 0, 8, 2, 1, 2, 0, 0, 2, 2],
#   [1, 4964, 0, 0, 0, 1, 1, 0, 1, 0],
#   [0, 0, 4936, 0, 0, 0, 3, 0, 0, 0],
#   [1, 0, 11, 4990, 0, 17, 15, 0, 3, 0],
#   [3, 0, 12, 3, 4967, 8, 11, 2, 0, 1],
#   [0, 0, 13, 2, 4, 4957, 3, 0, 0, 2],
#   [0, 1, 1, 0, 1, 0, 4950, 0, 0, 0],
#   [1, 0, 15, 0, 20, 14, 5, 4998, 1, 1],
#   [5, 0, 3, 0, 1, 0, 1, 0, 4983, 0],
#   [5, 35, 1, 3, 6, 1, 11, 0, 10, 4994]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.998892}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.998892
# Mean Classification Error 0.001108
# Mean Precision 0.9944953182076443
# Mean Recall 0.9944599999999999
# Mean Specificity 0.9993844444444445
# Mean F1-Score 0.9944616228492743

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn1_base',
#  'time': '2022-10-14 03:42:45.888660',
#  'type': 'test',
#  'Accuracy': [0.9296,
#   0.9349,
#   0.9039,
#   0.8709,
#   0.8994,
#   0.9004,
#   0.933,
#   0.9254,
#   0.9424,
#   0.9205],
#  'Classification Error': [0.0704,
#   0.0651,
#   0.0961,
#   0.1291,
#   0.1006,
#   0.0996,
#   0.067,
#   0.0746,
#   0.0576,
#   0.0795],
#  'TP': [665, 679, 374, 437, 510, 445, 611, 697, 703, 681],
#  'FP': [369, 330, 335, 728, 516, 441, 281, 443, 279, 476],
#  'TN': [8631, 8670, 8665, 8272, 8484, 8559, 8719, 8557, 8721, 8524],
#  'FN': [335, 321, 626, 563, 490, 555, 389, 303, 297, 319],
#  'Precision': [0.6431334622823984,
#   0.6729435084241824,
#   0.5275035260930888,
#   0.37510729613733906,
#   0.49707602339181284,
#   0.5022573363431151,
#   0.6849775784753364,
#   0.6114035087719298,
#   0.7158859470468432,
#   0.5885911840968021],
#  'Recall': [0.665,
#   0.679,
#   0.374,
#   0.437,
#   0.51,
#   0.445,
#   0.611,
#   0.697,
#   0.703,
#   0.681],
#  'Specificity': [0.959,
#   0.9633333333333334,
#   0.9627777777777777,
#   0.9191111111111111,
#   0.9426666666666667,
#   0.951,
#   0.9687777777777777,
#   0.9507777777777778,
#   0.969,
#   0.9471111111111111],
#  'F1-Score': [0.6538839724680433,
#   0.6759581881533102,
#   0.4376828554710357,
#   0.40369515011547347,
#   0.5034550839091807,
#   0.471898197242842,
#   0.6458773784355181,
#   0.6514018691588785,
#   0.7093844601412714,
#   0.631432545201669],
#  'confusion_matrix': [[665, 34, 96, 31, 32, 24, 13, 24, 79, 36],
#   [34, 679, 17, 29, 10, 11, 20, 18, 66, 125],
#   [32, 12, 374, 59, 75, 52, 54, 25, 9, 17],
#   [34, 24, 113, 437, 91, 222, 124, 55, 33, 32],
#   [32, 5, 129, 96, 510, 77, 85, 65, 16, 11],
#   [7, 6, 87, 158, 49, 445, 43, 70, 11, 10],
#   [15, 12, 74, 61, 67, 26, 611, 9, 6, 11],
#   [25, 7, 67, 62, 120, 107, 20, 697, 11, 24],
#   [104, 40, 18, 19, 21, 10, 9, 5, 703, 53],
#   [52, 181, 25, 48, 25, 26, 21, 32, 66, 681]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.91604}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.91604
# Mean Classification Error 0.08396
# Mean Precision 0.5818879371062847
# Mean Recall 0.5802
# Mean Specificity 0.9533555555555555
# Mean F1-Score 0.5784669700297222
