# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "cnn2_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn2_base',
#  'time': '2022-10-13 20:32:40.560191',
#  'type': 'train',
#  'Accuracy': [0.94426,
#   0.9555,
#   0.91962,
#   0.88974,
#   0.92714,
#   0.92368,
#   0.94984,
#   0.93754,
#   0.95982,
#   0.9447],
#  'Classification Error': [0.05574,
#   0.0445,
#   0.08038,
#   0.11026,
#   0.07286,
#   0.07632,
#   0.05016,
#   0.06246,
#   0.04018,
#   0.0553],
#  'TP': [3659, 3502, 2809, 3191, 3182, 1888, 3781, 3800, 4058, 3926],
#  'FP': [1446, 727, 1828, 3704, 1825, 704, 1289, 1923, 1067, 1691],
#  'TN': [43554, 44273, 43172, 41296, 43175, 44296, 43711, 43077, 43933, 43309],
#  'FN': [1341, 1498, 2191, 1809, 1818, 3112, 1219, 1200, 942, 1074],
#  'Precision': [0.7167482859941234,
#   0.8280917474580279,
#   0.6057795988785853,
#   0.46279912980420596,
#   0.6355102856001598,
#   0.7283950617283951,
#   0.7457593688362919,
#   0.6639874191857418,
#   0.7918048780487805,
#   0.6989496172333987],
#  'Recall': [0.7318,
#   0.7004,
#   0.5618,
#   0.6382,
#   0.6364,
#   0.3776,
#   0.7562,
#   0.76,
#   0.8116,
#   0.7852],
#  'Specificity': [0.9678666666666667,
#   0.9838444444444444,
#   0.9593777777777778,
#   0.9176888888888889,
#   0.9594444444444444,
#   0.9843555555555555,
#   0.9713555555555555,
#   0.9572666666666667,
#   0.9762888888888889,
#   0.9624222222222222],
#  'F1-Score': [0.7241959426026721,
#   0.7589121248239246,
#   0.582961502542285,
#   0.5365279529213955,
#   0.6359548316178675,
#   0.4973656480505796,
#   0.7509433962264149,
#   0.7087568777394386,
#   0.8015802469135802,
#   0.7395686163699728],
#  'confusion_matrix': [[3659, 185, 311, 132, 140, 53, 40, 69, 361, 155],
#   [90, 3502, 26, 21, 15, 15, 36, 21, 131, 372],
#   [239, 60, 2809, 319, 344, 350, 240, 146, 86, 44],
#   [128, 77, 515, 3191, 356, 1682, 434, 313, 82, 117],
#   [91, 35, 506, 264, 3182, 270, 257, 340, 35, 27],
#   [12, 6, 129, 294, 59, 1888, 31, 144, 10, 19],
#   [28, 74, 293, 347, 275, 153, 3781, 35, 25, 59],
#   [98, 59, 254, 259, 530, 500, 67, 3800, 20, 136],
#   [418, 205, 82, 75, 50, 27, 36, 29, 4058, 145],
#   [237, 797, 75, 98, 49, 62, 78, 103, 192, 3926]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.935184}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9351839999999999
# Mean Classification Error 0.064816
# Mean Precision 0.6877825392767709
# Mean Recall 0.67592
# Mean Specificity 0.9639911111111111
# Mean F1-Score 0.6736767139808131

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn2_base',
#  'time': '2022-10-13 20:32:41.410070',
#  'type': 'test',
#  'Accuracy': [0.9344,
#   0.9434,
#   0.903,
#   0.8762,
#   0.9142,
#   0.9177,
#   0.9436,
#   0.9272,
#   0.9496,
#   0.9295],
#  'Classification Error': [0.0656,
#   0.0566,
#   0.097,
#   0.1238,
#   0.0858,
#   0.0823,
#   0.0564,
#   0.0728,
#   0.0504,
#   0.0705],
#  'TP': [691, 626, 466, 571, 545, 350, 740, 719, 759, 727],
#  'FP': [347, 192, 436, 809, 403, 173, 304, 447, 263, 432],
#  'TN': [8653, 8808, 8564, 8191, 8597, 8827, 8696, 8553, 8737, 8568],
#  'FN': [309, 374, 534, 429, 455, 650, 260, 281, 241, 273],
#  'Precision': [0.6657032755298651,
#   0.7652811735941321,
#   0.516629711751663,
#   0.413768115942029,
#   0.5748945147679325,
#   0.6692160611854685,
#   0.7088122605363985,
#   0.6166380789022299,
#   0.7426614481409002,
#   0.6272648835202761],
#  'Recall': [0.691,
#   0.626,
#   0.466,
#   0.571,
#   0.545,
#   0.35,
#   0.74,
#   0.719,
#   0.759,
#   0.727],
#  'Specificity': [0.9614444444444444,
#   0.9786666666666667,
#   0.9515555555555556,
#   0.9101111111111111,
#   0.9552222222222222,
#   0.9807777777777777,
#   0.9662222222222222,
#   0.9503333333333334,
#   0.9707777777777777,
#   0.952],
#  'F1-Score': [0.678115799803729,
#   0.6886688668866886,
#   0.49001051524710837,
#   0.47983193277310926,
#   0.5595482546201231,
#   0.4596191726854892,
#   0.7240704500978473,
#   0.6638965835641736,
#   0.7507418397626112,
#   0.6734599351551644],
#  'confusion_matrix': [[691, 47, 77, 24, 30, 18, 9, 14, 81, 47],
#   [16, 626, 6, 11, 6, 2, 10, 7, 39, 95],
#   [55, 20, 466, 80, 95, 73, 46, 36, 19, 12],
#   [24, 10, 135, 571, 81, 338, 93, 75, 22, 31],
#   [21, 5, 108, 74, 545, 55, 59, 66, 8, 7],
#   [1, 1, 33, 71, 20, 350, 3, 40, 2, 2],
#   [11, 14, 74, 73, 75, 31, 740, 6, 6, 14],
#   [13, 17, 63, 59, 121, 104, 20, 719, 16, 34],
#   [106, 45, 19, 18, 20, 11, 7, 6, 759, 31],
#   [62, 215, 19, 19, 7, 18, 13, 31, 48, 727]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.92388}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9238800000000001
# Mean Classification Error 0.07612
# Mean Precision 0.6300869523870894
# Mean Recall 0.6194000000000001
# Mean Specificity 0.9577111111111112
# Mean F1-Score 0.6167963350596044
