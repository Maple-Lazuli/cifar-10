# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "cnn2_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn2_base',
#  'time': '2022-10-13 20:03:40.199312',
#  'type': 'train',
#  'Accuracy': [0.93144,
#   0.93526,
#   0.90652,
#   0.89364,
#   0.90932,
#   0.9029,
#   0.9426,
#   0.9162,
#   0.94622,
#   0.92938],
#  'Classification Error': [0.06856,
#   0.06474,
#   0.09348,
#   0.10636,
#   0.09068,
#   0.0971,
#   0.0574,
#   0.0838,
#   0.05378,
#   0.07062],
#  'TP': [3437, 3928, 2138, 1853, 2751, 2649, 3291, 3632, 3660, 2998],
#  'FP': [1865, 2165, 1812, 2171, 2285, 2504, 1161, 2822, 1349, 1529],
#  'TN': [43135, 42835, 43188, 42829, 42715, 42496, 43839, 42178, 43651, 43471],
#  'FN': [1563, 1072, 2862, 3147, 2249, 2351, 1709, 1368, 1340, 2002],
#  'Precision': [0.6482459449264428,
#   0.6446742163138027,
#   0.5412658227848102,
#   0.46048707753479123,
#   0.5462668784749801,
#   0.5140694740927615,
#   0.7392183288409704,
#   0.562751781840719,
#   0.7306847674186464,
#   0.6622487298431633],
#  'Recall': [0.6874,
#   0.7856,
#   0.4276,
#   0.3706,
#   0.5502,
#   0.5298,
#   0.6582,
#   0.7264,
#   0.732,
#   0.5996],
#  'Specificity': [0.9585555555555556,
#   0.9518888888888889,
#   0.9597333333333333,
#   0.9517555555555556,
#   0.9492222222222222,
#   0.9443555555555555,
#   0.9742,
#   0.9372888888888888,
#   0.9700222222222222,
#   0.9660222222222222],
#  'F1-Score': [0.6672490778489614,
#   0.7081943568015866,
#   0.47776536312849166,
#   0.4106826241134752,
#   0.5482263850139497,
#   0.5218162119570571,
#   0.6963605586119339,
#   0.6341889296315698,
#   0.7313417923868518,
#   0.6293691613309542],
#  'confusion_matrix': [[3437, 129, 435, 155, 200, 86, 47, 83, 526, 204],
#   [212, 3928, 109, 102, 62, 60, 135, 57, 325, 1103],
#   [228, 30, 2138, 399, 384, 308, 229, 109, 85, 40],
#   [53, 35, 346, 1853, 239, 763, 395, 193, 59, 88],
#   [153, 25, 655, 341, 2751, 287, 396, 336, 55, 37],
#   [37, 22, 457, 1141, 235, 2649, 153, 359, 40, 60],
#   [29, 30, 262, 306, 268, 126, 3291, 56, 25, 59],
#   [148, 98, 385, 426, 722, 586, 167, 3632, 47, 243],
#   [513, 182, 127, 117, 81, 47, 74, 40, 3660, 168],
#   [190, 521, 86, 160, 58, 88, 113, 135, 178, 2998]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.921348}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9213480000000001
# Mean Classification Error 0.07865200000000001
# Mean Precision 0.6049913022071088
# Mean Recall 0.60674
# Mean Specificity 0.9563044444444445
# Mean F1-Score 0.6025194460824832

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn2_base',
#  'time': '2022-10-13 20:03:41.017232',
#  'type': 'test',
#  'Accuracy': [0.9283,
#   0.9317,
#   0.9021,
#   0.8934,
#   0.9039,
#   0.899,
#   0.9441,
#   0.9114,
#   0.941,
#   0.9253],
#  'Classification Error': [0.0717,
#   0.0683,
#   0.0979,
#   0.1066,
#   0.0961,
#   0.101,
#   0.0559,
#   0.0886,
#   0.059,
#   0.0747],
#  'TP': [679, 772, 397, 363, 518, 514, 676, 709, 708, 565],
#  'FP': [396, 455, 376, 429, 479, 524, 235, 595, 298, 312],
#  'TN': [8604, 8545, 8624, 8571, 8521, 8476, 8765, 8405, 8702, 8688],
#  'FN': [321, 228, 603, 637, 482, 486, 324, 291, 292, 435],
#  'Precision': [0.6316279069767442,
#   0.6291768541157294,
#   0.5135834411384217,
#   0.4583333333333333,
#   0.5195586760280843,
#   0.4951830443159923,
#   0.7420417124039517,
#   0.5437116564417178,
#   0.7037773359840954,
#   0.6442417331812998],
#  'Recall': [0.679,
#   0.772,
#   0.397,
#   0.363,
#   0.518,
#   0.514,
#   0.676,
#   0.709,
#   0.708,
#   0.565],
#  'Specificity': [0.956,
#   0.9494444444444444,
#   0.9582222222222222,
#   0.9523333333333334,
#   0.9467777777777778,
#   0.9417777777777778,
#   0.9738888888888889,
#   0.9338888888888889,
#   0.9668888888888889,
#   0.9653333333333334],
#  'F1-Score': [0.6544578313253013,
#   0.6933093848226314,
#   0.44782853919909754,
#   0.4051339285714286,
#   0.5187781672508763,
#   0.5044160942100098,
#   0.7074829931972789,
#   0.6154513888888888,
#   0.7058823529411764,
#   0.6020245071923283],
#  'confusion_matrix': [[679, 38, 87, 28, 41, 25, 6, 21, 107, 43],
#   [35, 772, 22, 16, 16, 12, 18, 15, 81, 240],
#   [46, 7, 397, 73, 72, 67, 57, 25, 14, 15],
#   [11, 10, 65, 363, 49, 145, 73, 44, 13, 19],
#   [31, 6, 153, 90, 518, 53, 68, 60, 13, 5],
#   [11, 7, 106, 218, 51, 514, 29, 86, 8, 8],
#   [8, 9, 48, 63, 72, 19, 676, 3, 4, 9],
#   [25, 14, 72, 85, 160, 133, 36, 709, 19, 51],
#   [122, 32, 30, 21, 15, 17, 11, 5, 708, 45],
#   [32, 105, 20, 43, 6, 15, 26, 32, 33, 565]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.91802}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9180200000000001
# Mean Classification Error 0.08198000000000001
# Mean Precision 0.5881235693919369
# Mean Recall 0.5901
# Mean Specificity 0.9544555555555556
# Mean F1-Score 0.5854765187599018
