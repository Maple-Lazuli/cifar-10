# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "cnn3_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn3_base',
#  'time': '2022-10-13 20:05:17.798945',
#  'type': 'train',
#  'Accuracy': [0.94126,
#   0.95386,
#   0.9276,
#   0.9044,
#   0.9016,
#   0.92178,
#   0.94824,
#   0.949,
#   0.95802,
#   0.95212],
#  'Classification Error': [0.05874,
#   0.04614,
#   0.0724,
#   0.0956,
#   0.0984,
#   0.07822,
#   0.05176,
#   0.051,
#   0.04198,
#   0.04788],
#  'TP': [3792, 4172, 2383, 2531, 3792, 2408, 3615, 3599, 4054, 3601],
#  'FP': [1729, 1479, 1003, 2311, 3712, 1319, 1203, 1149, 1153, 995],
#  'TN': [43271, 43521, 43997, 42689, 41288, 43681, 43797, 43851, 43847, 44005],
#  'FN': [1208, 828, 2617, 2469, 1208, 2592, 1385, 1401, 946, 1399],
#  'Precision': [0.6868320956348487,
#   0.7382764112546452,
#   0.703780271707029,
#   0.5227178851714168,
#   0.5053304904051172,
#   0.6460960558089617,
#   0.7503113325031133,
#   0.7580033698399326,
#   0.7785673132321874,
#   0.7835073977371627],
#  'Recall': [0.7584,
#   0.8344,
#   0.4766,
#   0.5062,
#   0.7584,
#   0.4816,
#   0.723,
#   0.7198,
#   0.8108,
#   0.7202],
#  'Specificity': [0.9615777777777778,
#   0.9671333333333333,
#   0.9777111111111111,
#   0.9486444444444444,
#   0.9175111111111112,
#   0.9706888888888889,
#   0.9732666666666666,
#   0.9744666666666667,
#   0.9743777777777778,
#   0.9778888888888889],
#  'F1-Score': [0.7208440262332477,
#   0.7834006196601258,
#   0.5683281659909374,
#   0.5143263564316195,
#   0.6065259117082533,
#   0.5518505786639165,
#   0.7364025259727031,
#   0.7384078785391874,
#   0.7943568139512099,
#   0.7505210504376824],
#  'confusion_matrix': [[3792, 164, 443, 140, 159, 76, 45, 99, 444, 159],
#   [151, 4172, 84, 92, 53, 41, 104, 45, 157, 752],
#   [127, 22, 2383, 208, 176, 215, 138, 77, 24, 16],
#   [77, 33, 344, 2531, 195, 1011, 312, 204, 65, 70],
#   [172, 52, 917, 648, 3792, 585, 574, 611, 79, 74],
#   [34, 11, 249, 627, 76, 2408, 82, 202, 17, 21],
#   [29, 33, 291, 357, 200, 187, 3615, 38, 27, 41],
#   [43, 20, 137, 198, 260, 368, 29, 3599, 8, 86],
#   [411, 190, 88, 111, 48, 49, 52, 24, 4054, 180],
#   [164, 303, 64, 88, 41, 60, 49, 101, 125, 3601]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.935788}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.935788
# Mean Classification Error 0.064212
# Mean Precision 0.6873422623294414
# Mean Recall 0.6789400000000001
# Mean Specificity 0.9643266666666668
# Mean F1-Score 0.6764963927588884

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn3_base',
#  'time': '2022-10-13 20:05:18.653447',
#  'type': 'test',
#  'Accuracy': [0.9282,
#   0.9459,
#   0.915,
#   0.888,
#   0.8871,
#   0.912,
#   0.9409,
#   0.9366,
#   0.9455,
#   0.9388],
#  'Classification Error': [0.0718,
#   0.0541,
#   0.085,
#   0.112,
#   0.1129,
#   0.088,
#   0.0591,
#   0.0634,
#   0.0545,
#   0.0612],
#  'TP': [710, 785, 397, 428, 675, 449, 685, 662, 753, 646],
#  'FP': [428, 326, 247, 548, 804, 329, 276, 296, 298, 258],
#  'TN': [8572, 8674, 8753, 8452, 8196, 8671, 8724, 8704, 8702, 8742],
#  'FN': [290, 215, 603, 572, 325, 551, 315, 338, 247, 354],
#  'Precision': [0.6239015817223199,
#   0.7065706570657065,
#   0.6164596273291926,
#   0.4385245901639344,
#   0.4563894523326572,
#   0.577120822622108,
#   0.7127991675338189,
#   0.6910229645093946,
#   0.7164605137963844,
#   0.7146017699115044],
#  'Recall': [0.71,
#   0.785,
#   0.397,
#   0.428,
#   0.675,
#   0.449,
#   0.685,
#   0.662,
#   0.753,
#   0.646],
#  'Specificity': [0.9524444444444444,
#   0.9637777777777777,
#   0.9725555555555555,
#   0.9391111111111111,
#   0.9106666666666666,
#   0.9634444444444444,
#   0.9693333333333334,
#   0.9671111111111111,
#   0.9668888888888889,
#   0.9713333333333334],
#  'F1-Score': [0.6641721234798877,
#   0.7437233538607295,
#   0.48296836982968366,
#   0.43319838056680154,
#   0.5445744251714402,
#   0.5050618672665916,
#   0.6986231514533402,
#   0.676200204290092,
#   0.734275962944905,
#   0.6785714285714286],
#  'confusion_matrix': [[710, 33, 96, 43, 37, 24, 10, 22, 107, 56],
#   [29, 785, 22, 24, 10, 7, 22, 9, 49, 154],
#   [29, 7, 397, 45, 44, 56, 29, 18, 12, 7],
#   [19, 13, 82, 428, 58, 205, 80, 57, 15, 19],
#   [37, 14, 179, 165, 675, 122, 121, 133, 16, 17],
#   [12, 7, 78, 123, 23, 449, 17, 56, 7, 6],
#   [15, 5, 65, 71, 60, 28, 685, 13, 6, 13],
#   [6, 6, 43, 53, 70, 79, 12, 662, 3, 24],
#   [96, 46, 21, 27, 18, 17, 13, 2, 753, 58],
#   [47, 84, 17, 21, 5, 13, 11, 28, 32, 646]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.9238}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9238
# Mean Classification Error 0.07620000000000002
# Mean Precision 0.6253851146987022
# Mean Recall 0.619
# Mean Specificity 0.9576666666666668
# Mean F1-Score 0.6161369267434901
