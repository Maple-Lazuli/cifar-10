# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np
plt.style.use('ggplot')

# %%
results_dir ="../results"
report = "cnn3_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn3_base',
#  'time': '2022-10-14 00:36:29.143507',
#  'type': 'train',
#  'Accuracy': [0.96126,
#   0.96774,
#   0.9425,
#   0.91808,
#   0.94038,
#   0.93602,
#   0.95026,
#   0.96018,
#   0.9725,
#   0.96492],
#  'Classification Error': [0.03874,
#   0.03226,
#   0.0575,
#   0.08192,
#   0.05962,
#   0.06398,
#   0.04974,
#   0.03982,
#   0.0275,
#   0.03508],
#  'TP': [4121, 4479, 3394, 2930, 3646, 2835, 4206, 3896, 4430, 3909],
#  'FP': [1058, 1092, 1269, 2026, 1627, 1034, 1693, 887, 805, 663],
#  'TN': [43942, 43908, 43731, 42974, 43373, 43966, 43307, 44113, 44195, 44337],
#  'FN': [879, 521, 1606, 2070, 1354, 2165, 794, 1104, 570, 1091],
#  'Precision': [0.795713458196563,
#   0.8039849219170705,
#   0.7278576024018872,
#   0.5912025827280064,
#   0.6914469941209938,
#   0.7327474799689843,
#   0.7130022037633498,
#   0.8145515366924524,
#   0.8462273161413563,
#   0.85498687664042],
#  'Recall': [0.8242,
#   0.8958,
#   0.6788,
#   0.586,
#   0.7292,
#   0.567,
#   0.8412,
#   0.7792,
#   0.886,
#   0.7818],
#  'Specificity': [0.9764888888888889,
#   0.9757333333333333,
#   0.9718,
#   0.9549777777777778,
#   0.9638444444444444,
#   0.9770222222222222,
#   0.9623777777777778,
#   0.9802888888888889,
#   0.9821111111111112,
#   0.9852666666666666],
#  'F1-Score': [0.80970625798212,
#   0.8474127329486331,
#   0.7024733519610887,
#   0.588589795098433,
#   0.7098218631363769,
#   0.6393054459352803,
#   0.771813927883292,
#   0.7964836962077072,
#   0.8656570591108941,
#   0.8167572085248641],
#  'confusion_matrix': [[4121, 93, 234, 108, 112, 51, 26, 66, 221, 147],
#   [130, 4479, 68, 41, 28, 40, 36, 35, 124, 590],
#   [134, 13, 3394, 277, 266, 246, 167, 120, 30, 16],
#   [64, 22, 256, 2930, 198, 928, 219, 225, 47, 67],
#   [63, 16, 366, 286, 3646, 273, 210, 370, 25, 18],
#   [24, 5, 153, 548, 85, 2835, 57, 132, 10, 20],
#   [50, 45, 323, 497, 314, 292, 4206, 81, 28, 63],
#   [32, 17, 108, 146, 267, 230, 28, 3896, 4, 55],
#   [280, 89, 66, 103, 48, 51, 33, 20, 4430, 115],
#   [102, 221, 32, 64, 36, 54, 18, 55, 81, 3909]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.951384}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9513839999999998
# Mean Classification Error 0.048616
# Mean Precision 0.7571720972571084
# Mean Recall 0.75692
# Mean Specificity 0.9729911111111111
# Mean F1-Score 0.754802133878869

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn3_base',
#  'time': '2022-10-14 00:36:29.982566',
#  'type': 'test',
#  'Accuracy': [0.9334,
#   0.9485,
#   0.915,
#   0.8934,
#   0.9156,
#   0.9149,
#   0.9361,
#   0.94,
#   0.9504,
#   0.9445],
#  'Classification Error': [0.0666,
#   0.0515,
#   0.085,
#   0.1066,
#   0.0844,
#   0.0851,
#   0.0639,
#   0.06,
#   0.0496,
#   0.0555],
#  'TP': [699, 805, 518, 447, 584, 470, 790, 685, 780, 681],
#  'FP': [365, 320, 368, 513, 428, 321, 429, 285, 276, 236],
#  'TN': [8635, 8680, 8632, 8487, 8572, 8679, 8571, 8715, 8724, 8764],
#  'FN': [301, 195, 482, 553, 416, 530, 210, 315, 220, 319],
#  'Precision': [0.6569548872180451,
#   0.7155555555555555,
#   0.5846501128668171,
#   0.465625,
#   0.5770750988142292,
#   0.5941845764854614,
#   0.6480721903199343,
#   0.7061855670103093,
#   0.7386363636363636,
#   0.742639040348964],
#  'Recall': [0.699, 0.805, 0.518, 0.447, 0.584, 0.47, 0.79, 0.685, 0.78, 0.681],
#  'Specificity': [0.9594444444444444,
#   0.9644444444444444,
#   0.9591111111111111,
#   0.943,
#   0.9524444444444444,
#   0.9643333333333334,
#   0.9523333333333334,
#   0.9683333333333334,
#   0.9693333333333334,
#   0.9737777777777777],
#  'F1-Score': [0.6773255813953488,
#   0.7576470588235293,
#   0.5493107104984094,
#   0.45612244897959187,
#   0.5805168986083499,
#   0.5248464544946957,
#   0.7120324470482198,
#   0.6954314720812182,
#   0.7587548638132297,
#   0.7104851330203443],
#  'confusion_matrix': [[699, 29, 81, 40, 30, 18, 10, 25, 85, 47],
#   [43, 805, 11, 20, 9, 15, 11, 11, 59, 141],
#   [46, 9, 518, 71, 83, 66, 39, 39, 12, 3],
#   [20, 11, 62, 447, 52, 223, 53, 52, 17, 23],
#   [20, 5, 99, 92, 584, 65, 54, 78, 7, 8],
#   [6, 4, 61, 130, 29, 470, 18, 60, 5, 8],
#   [20, 17, 89, 106, 100, 53, 790, 14, 3, 27],
#   [10, 5, 42, 48, 76, 65, 10, 685, 5, 24],
#   [95, 36, 23, 26, 28, 16, 8, 6, 780, 38],
#   [41, 79, 14, 20, 9, 9, 7, 30, 27, 681]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.92918}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9291799999999999
# Mean Classification Error 0.07082
# Mean Precision 0.6429578392255679
# Mean Recall 0.6459
# Mean Specificity 0.9606555555555556
# Mean F1-Score 0.6422473068762937
