# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "cnn3_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'cnn3_base',
#  'time': '2022-10-13 20:35:57.954886',
#  'type': 'train',
#  'Accuracy': [0.96604,
#   0.9776,
#   0.93758,
#   0.92124,
#   0.9454,
#   0.93848,
#   0.96576,
#   0.96406,
#   0.97768,
#   0.9678],
#  'Classification Error': [0.03396,
#   0.0224,
#   0.06242,
#   0.07876,
#   0.0546,
#   0.06152,
#   0.03424,
#   0.03594,
#   0.02232,
#   0.0322],
#  'TP': [4055, 4370, 3716, 3078, 3540, 3350, 3815, 4220, 4548, 4349],
#  'FP': [753, 490, 1837, 2016, 1270, 1426, 527, 1017, 664, 959],
#  'TN': [44247, 44510, 43163, 42984, 43730, 43574, 44473, 43983, 44336, 44041],
#  'FN': [945, 630, 1284, 1922, 1460, 1650, 1185, 780, 452, 651],
#  'Precision': [0.8433860232945092,
#   0.8991769547325102,
#   0.6691878264001441,
#   0.6042402826855123,
#   0.735966735966736,
#   0.7014237855946399,
#   0.8786273606632888,
#   0.805804850105022,
#   0.8726016884113584,
#   0.8193293142426527],
#  'Recall': [0.811,
#   0.874,
#   0.7432,
#   0.6156,
#   0.708,
#   0.67,
#   0.763,
#   0.844,
#   0.9096,
#   0.8698],
#  'Specificity': [0.9832666666666666,
#   0.9891111111111112,
#   0.9591777777777778,
#   0.9552,
#   0.9717777777777777,
#   0.9683111111111111,
#   0.9882888888888889,
#   0.9774,
#   0.9852444444444445,
#   0.9786888888888889],
#  'F1-Score': [0.8268760195758565,
#   0.8864097363083163,
#   0.7042547142992513,
#   0.6098672478700218,
#   0.7217125382262997,
#   0.6853518821603928,
#   0.816741597088418,
#   0.8244602911009085,
#   0.8907168037602821,
#   0.8438106325184322],
#  'confusion_matrix': [[4055, 61, 154, 82, 85, 37, 41, 36, 153, 104],
#   [56, 4370, 19, 25, 16, 11, 33, 10, 64, 256],
#   [280, 22, 3716, 377, 397, 278, 281, 114, 55, 33],
#   [54, 31, 299, 3078, 309, 744, 348, 144, 38, 49],
#   [78, 8, 286, 226, 3540, 188, 238, 210, 18, 18],
#   [27, 10, 176, 703, 165, 3350, 129, 183, 10, 23],
#   [19, 17, 141, 149, 94, 68, 3815, 11, 9, 19],
#   [28, 17, 95, 220, 307, 250, 48, 4220, 14, 38],
#   [259, 102, 47, 50, 42, 18, 23, 12, 4548, 111],
#   [144, 362, 67, 90, 45, 56, 44, 60, 91, 4349]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.956164}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.956164
# Mean Classification Error 0.043836
# Mean Precision 0.7829744822096374
# Mean Recall 0.7808200000000001
# Mean Specificity 0.9756466666666667
# Mean F1-Score 0.7810201462908178

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'cnn3_base',
#  'time': '2022-10-13 20:35:58.837480',
#  'type': 'test',
#  'Accuracy': [0.9381,
#   0.9524,
#   0.9072,
#   0.8914,
#   0.9163,
#   0.9098,
#   0.9484,
#   0.9321,
#   0.953,
#   0.9401],
#  'Classification Error': [0.0619,
#   0.0476,
#   0.0928,
#   0.1086,
#   0.0837,
#   0.0902,
#   0.0516,
#   0.0679,
#   0.047,
#   0.0599],
#  'TP': [688, 742, 580, 437, 547, 536, 698, 690, 786, 740],
#  'FP': [307, 218, 508, 523, 384, 438, 214, 369, 256, 339],
#  'TN': [8693, 8782, 8492, 8477, 8616, 8562, 8786, 8631, 8744, 8661],
#  'FN': [312, 258, 420, 563, 453, 464, 302, 310, 214, 260],
#  'Precision': [0.6914572864321608,
#   0.7729166666666667,
#   0.5330882352941176,
#   0.4552083333333333,
#   0.5875402792696026,
#   0.5503080082135524,
#   0.7653508771929824,
#   0.6515580736543909,
#   0.7543186180422264,
#   0.6858202038924931],
#  'Recall': [0.688, 0.742, 0.58, 0.437, 0.547, 0.536, 0.698, 0.69, 0.786, 0.74],
#  'Specificity': [0.9658888888888889,
#   0.9757777777777777,
#   0.9435555555555556,
#   0.9418888888888889,
#   0.9573333333333334,
#   0.9513333333333334,
#   0.9762222222222222,
#   0.959,
#   0.9715555555555555,
#   0.9623333333333334],
#  'F1-Score': [0.6897243107769423,
#   0.7571428571428572,
#   0.5555555555555555,
#   0.4459183673469388,
#   0.5665458311755567,
#   0.5430597771023303,
#   0.7301255230125523,
#   0.6702282661486159,
#   0.7698334965719883,
#   0.7118807118807119],
#  'confusion_matrix': [[688, 25, 56, 29, 31, 19, 13, 19, 72, 43],
#   [32, 742, 12, 16, 9, 6, 9, 5, 36, 93],
#   [68, 15, 580, 86, 108, 82, 58, 51, 27, 13],
#   [20, 12, 68, 437, 85, 184, 78, 40, 19, 17],
#   [20, 2, 92, 72, 547, 60, 62, 69, 4, 3],
#   [7, 8, 69, 186, 41, 536, 31, 80, 5, 11],
#   [12, 12, 53, 48, 45, 20, 698, 6, 8, 10],
#   [21, 8, 39, 67, 110, 69, 22, 690, 6, 27],
#   [92, 41, 13, 19, 14, 12, 15, 7, 786, 43],
#   [40, 135, 18, 40, 10, 12, 14, 33, 37, 740]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.92888}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9288799999999998
# Mean Classification Error 0.07112
# Mean Precision 0.6447566581991526
# Mean Recall 0.6444000000000001
# Mean Specificity 0.9604888888888888
# Mean F1-Score 0.6440014696714049
