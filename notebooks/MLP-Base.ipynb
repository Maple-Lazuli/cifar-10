# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np
plt.style.use('ggplot')

# %%
results_dir ="../results"
report = "mlp_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'mlp_base',
#  'time': '2022-10-13 20:22:57.364809',
#  'type': 'train',
#  'Accuracy': [0.99232,
#   0.99738,
#   0.98896,
#   0.98954,
#   0.99008,
#   0.9915,
#   0.9939,
#   0.9946,
#   0.99422,
#   0.99646],
#  'Classification Error': [0.00768,
#   0.00262,
#   0.01104,
#   0.01046,
#   0.00992,
#   0.0085,
#   0.0061,
#   0.0054,
#   0.00578,
#   0.00354],
#  'TP': [4854, 4929, 4693, 4645, 4819, 4865, 4913, 4774, 4813, 4919],
#  'FP': [238, 60, 245, 168, 315, 290, 218, 44, 102, 96],
#  'TN': [44762, 44940, 44755, 44832, 44685, 44710, 44782, 44956, 44898, 44904],
#  'FN': [146, 71, 307, 355, 181, 135, 87, 226, 187, 81],
#  'Precision': [0.9532600157109191,
#   0.9879735417919423,
#   0.9503847711624139,
#   0.9650945356326616,
#   0.9386443319049474,
#   0.9437439379243453,
#   0.957513155330345,
#   0.9908675799086758,
#   0.9792472024415056,
#   0.9808574277168495],
#  'Recall': [0.9708,
#   0.9858,
#   0.9386,
#   0.929,
#   0.9638,
#   0.973,
#   0.9826,
#   0.9548,
#   0.9626,
#   0.9838],
#  'Specificity': [0.9947111111111111,
#   0.9986666666666667,
#   0.9945555555555555,
#   0.9962666666666666,
#   0.993,
#   0.9935555555555555,
#   0.9951555555555556,
#   0.9990222222222223,
#   0.9977333333333334,
#   0.9978666666666667],
#  'F1-Score': [0.9619500594530321,
#   0.9868855741315447,
#   0.9444556248742202,
#   0.946703352695404,
#   0.9510558515887112,
#   0.9581486952240277,
#   0.9698943835751654,
#   0.9724994907313098,
#   0.9708522440746344,
#   0.982326510234648],
#  'confusion_matrix': [[4854, 4, 81, 8, 7, 6, 0, 6, 105, 21],
#   [11, 4929, 0, 3, 1, 3, 2, 2, 16, 22],
#   [30, 5, 4693, 56, 70, 21, 27, 25, 7, 4],
#   [5, 4, 30, 4645, 28, 46, 14, 32, 3, 6],
#   [30, 5, 103, 36, 4819, 20, 23, 76, 16, 6],
#   [8, 3, 29, 135, 32, 4865, 12, 58, 5, 8],
#   [5, 8, 45, 85, 27, 23, 4913, 13, 5, 7],
#   [11, 1, 5, 7, 7, 8, 2, 4774, 1, 2],
#   [30, 19, 11, 16, 6, 5, 4, 6, 4813, 5],
#   [16, 22, 3, 9, 3, 3, 3, 8, 29, 4919]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.992896}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9928960000000002
# Mean Classification Error 0.007104000000000001
# Mean Precision 0.9647586499524605
# Mean Recall 0.96448
# Mean Specificity 0.9960533333333332
# Mean F1-Score 0.9644771786582698

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'mlp_base',
#  'time': '2022-10-13 20:22:58.173963',
#  'type': 'test',
#  'Accuracy': [0.9178,
#   0.9252,
#   0.8827,
#   0.8716,
#   0.8882,
#   0.8735,
#   0.9098,
#   0.9213,
#   0.931,
#   0.9133],
#  'Classification Error': [0.0822,
#   0.0748,
#   0.1173,
#   0.1284,
#   0.1118,
#   0.1265,
#   0.0902,
#   0.0787,
#   0.069,
#   0.0867],
#  'TP': [605, 584, 381, 343, 462, 445, 592, 545, 643, 572],
#  'FP': [427, 332, 554, 627, 580, 710, 494, 332, 333, 439],
#  'TN': [8573, 8668, 8446, 8373, 8420, 8290, 8506, 8668, 8667, 8561],
#  'FN': [395, 416, 619, 657, 538, 555, 408, 455, 357, 428],
#  'Precision': [0.5862403100775194,
#   0.6375545851528385,
#   0.40748663101604277,
#   0.35360824742268043,
#   0.44337811900191937,
#   0.3852813852813853,
#   0.5451197053406999,
#   0.621436716077537,
#   0.6588114754098361,
#   0.5657764589515332],
#  'Recall': [0.605,
#   0.584,
#   0.381,
#   0.343,
#   0.462,
#   0.445,
#   0.592,
#   0.545,
#   0.643,
#   0.572],
#  'Specificity': [0.9525555555555556,
#   0.9631111111111111,
#   0.9384444444444444,
#   0.9303333333333333,
#   0.9355555555555556,
#   0.9211111111111111,
#   0.9451111111111111,
#   0.9631111111111111,
#   0.963,
#   0.9512222222222222],
#  'F1-Score': [0.5954724409448819,
#   0.6096033402922756,
#   0.3937984496124031,
#   0.34822335025380713,
#   0.4524975514201763,
#   0.41299303944315546,
#   0.5675934803451582,
#   0.5807139051678211,
#   0.6508097165991903,
#   0.5688712083540527],
#  'confusion_matrix': [[605, 39, 88, 26, 38, 22, 7, 31, 117, 59],
#   [37, 584, 10, 19, 10, 8, 22, 20, 60, 146],
#   [64, 22, 381, 78, 134, 79, 80, 53, 16, 28],
#   [26, 32, 84, 343, 62, 201, 92, 69, 27, 34],
#   [58, 17, 145, 60, 462, 63, 94, 99, 24, 20],
#   [22, 15, 110, 257, 95, 445, 74, 94, 15, 28],
#   [26, 31, 89, 110, 89, 72, 592, 39, 17, 21],
#   [23, 22, 46, 54, 64, 59, 10, 545, 18, 36],
#   [93, 71, 21, 22, 28, 22, 13, 7, 643, 56],
#   [46, 167, 26, 31, 18, 29, 16, 43, 63, 572]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.90344}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9034400000000001
# Mean Classification Error 0.09656
# Mean Precision 0.5204693633731992
# Mean Recall 0.5172
# Mean Specificity 0.9463555555555555
# Mean F1-Score 0.5180576482432921
