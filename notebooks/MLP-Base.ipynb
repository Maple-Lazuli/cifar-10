# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "mlp_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'mlp_base',
#  'time': '2022-10-13 19:58:49.466317',
#  'type': 'train',
#  'Accuracy': [0.97526,
#   0.98266,
#   0.95904,
#   0.9525,
#   0.95918,
#   0.96096,
#   0.97058,
#   0.98122,
#   0.97938,
#   0.9807],
#  'Classification Error': [0.02474,
#   0.01734,
#   0.04096,
#   0.0475,
#   0.04082,
#   0.03904,
#   0.02942,
#   0.01878,
#   0.02062,
#   0.0193],
#  'TP': [4414, 4793, 3687, 3564, 4354, 4272, 4327, 4340, 4522, 4264],
#  'FP': [651, 660, 735, 939, 1395, 1224, 798, 279, 553, 229],
#  'TN': [44349, 44340, 44265, 44061, 43605, 43776, 44202, 44721, 44447, 44771],
#  'FN': [586, 207, 1313, 1436, 646, 728, 673, 660, 478, 736],
#  'Precision': [0.8714708785784797,
#   0.8789657069503026,
#   0.833785617367707,
#   0.7914723517654897,
#   0.7573491041920334,
#   0.777292576419214,
#   0.8442926829268292,
#   0.9395973154362416,
#   0.8910344827586207,
#   0.9490318272868907],
#  'Recall': [0.8828,
#   0.9586,
#   0.7374,
#   0.7128,
#   0.8708,
#   0.8544,
#   0.8654,
#   0.868,
#   0.9044,
#   0.8528],
#  'Specificity': [0.9855333333333334,
#   0.9853333333333333,
#   0.9836666666666667,
#   0.9791333333333333,
#   0.969,
#   0.9728,
#   0.9822666666666666,
#   0.9938,
#   0.9877111111111111,
#   0.9949111111111111],
#  'F1-Score': [0.8770988574267263,
#   0.9170573041232183,
#   0.7826363829335597,
#   0.7500789224455435,
#   0.8101218718020282,
#   0.8140243902439025,
#   0.854716049382716,
#   0.9023807048549746,
#   0.897667493796526,
#   0.8983461497945856],
#  'confusion_matrix': [[4414, 27, 130, 60, 61, 26, 15, 47, 184, 101],
#   [66, 4793, 29, 24, 11, 15, 43, 23, 117, 332],
#   [111, 13, 3687, 152, 175, 86, 96, 73, 8, 21],
#   [22, 19, 174, 3564, 77, 316, 181, 81, 34, 35],
#   [83, 14, 502, 189, 4354, 125, 185, 214, 59, 24],
#   [26, 5, 188, 599, 108, 4272, 118, 130, 13, 37],
#   [30, 19, 159, 302, 104, 83, 4327, 24, 21, 56],
#   [16, 4, 72, 50, 61, 45, 10, 4340, 6, 15],
#   [193, 56, 42, 41, 39, 18, 13, 36, 4522, 115],
#   [39, 50, 17, 19, 10, 14, 12, 32, 36, 4264]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.970148}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9701480000000002
# Mean Classification Error 0.029852
# Mean Precision 0.853429254368181
# Mean Recall 0.85074
# Mean Specificity 0.9834155555555556
# Mean F1-Score 0.8504128126803779

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'mlp_base',
#  'time': '2022-10-13 19:58:50.260781',
#  'type': 'test',
#  'Accuracy': [0.9175,
#   0.9215,
#   0.8941,
#   0.8749,
#   0.8847,
#   0.8791,
#   0.9152,
#   0.9257,
#   0.9286,
#   0.9123],
#  'Classification Error': [0.0825,
#   0.0785,
#   0.1059,
#   0.1251,
#   0.1153,
#   0.1209,
#   0.0848,
#   0.0743,
#   0.0714,
#   0.0877],
#  'TP': [619, 666, 393, 323, 505, 500, 576, 548, 664, 474],
#  'FP': [444, 451, 452, 574, 658, 709, 424, 291, 378, 351],
#  'TN': [8556, 8549, 8548, 8426, 8342, 8291, 8576, 8709, 8622, 8649],
#  'FN': [381, 334, 607, 677, 495, 500, 424, 452, 336, 526],
#  'Precision': [0.5823142050799623,
#   0.5962399283795882,
#   0.4650887573964497,
#   0.3600891861761427,
#   0.4342218400687876,
#   0.41356492969396197,
#   0.576,
#   0.6531585220500596,
#   0.6372360844529751,
#   0.5745454545454546],
#  'Recall': [0.619,
#   0.666,
#   0.393,
#   0.323,
#   0.505,
#   0.5,
#   0.576,
#   0.548,
#   0.664,
#   0.474],
#  'Specificity': [0.9506666666666667,
#   0.9498888888888889,
#   0.9497777777777778,
#   0.9362222222222222,
#   0.9268888888888889,
#   0.9212222222222223,
#   0.9528888888888889,
#   0.9676666666666667,
#   0.958,
#   0.961],
#  'F1-Score': [0.6000969461948618,
#   0.6291922531884743,
#   0.42601626016260163,
#   0.3405376910911966,
#   0.4669440591770689,
#   0.45269352648257133,
#   0.576,
#   0.5959760739532356,
#   0.6503428011753183,
#   0.5194520547945206],
#  'confusion_matrix': [[619, 43, 73, 32, 45, 22, 14, 37, 113, 65],
#   [38, 666, 15, 27, 14, 11, 27, 24, 80, 215],
#   [57, 16, 393, 73, 105, 52, 75, 42, 10, 22],
#   [13, 21, 82, 323, 63, 176, 93, 70, 20, 36],
#   [46, 13, 166, 79, 505, 100, 100, 105, 31, 18],
#   [17, 16, 114, 254, 85, 500, 70, 107, 19, 27],
#   [27, 16, 74, 113, 82, 44, 576, 24, 13, 31],
#   [13, 16, 42, 43, 64, 57, 13, 548, 10, 33],
#   [118, 67, 18, 25, 22, 17, 15, 17, 664, 79],
#   [52, 126, 23, 31, 15, 21, 17, 26, 40, 474]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.90536}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9053599999999999
# Mean Classification Error 0.09464
# Mean Precision 0.5292458907843381
# Mean Recall 0.5268
# Mean Specificity 0.9474222222222222
# Mean F1-Score 0.5257251666219849
