# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "lenet_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'lenet_base',
#  'time': '2022-10-13 20:26:09.275604',
#  'type': 'train',
#  'Accuracy': [0.96186,
#   0.9706,
#   0.94182,
#   0.91236,
#   0.94212,
#   0.93038,
#   0.96072,
#   0.96342,
#   0.97032,
#   0.96564],
#  'Classification Error': [0.03814,
#   0.0294,
#   0.05818,
#   0.08764,
#   0.05788,
#   0.06962,
#   0.03928,
#   0.03658,
#   0.02968,
#   0.03436],
#  'TP': [3806, 4456, 2963, 3116, 3755, 3455, 4011, 3814, 4550, 4055],
#  'FP': [713, 926, 872, 2498, 1649, 1936, 975, 643, 1034, 773],
#  'TN': [44287, 44074, 44128, 42502, 43351, 43064, 44025, 44357, 43966, 44227],
#  'FN': [1194, 544, 2037, 1884, 1245, 1545, 989, 1186, 450, 945],
#  'Precision': [0.8422217304713432,
#   0.8279450018580453,
#   0.7726205997392438,
#   0.5550409690060563,
#   0.6948556624722427,
#   0.6408829530699314,
#   0.8044524669073405,
#   0.855732555530626,
#   0.8148280802292264,
#   0.8398922949461475],
#  'Recall': [0.7612,
#   0.8912,
#   0.5926,
#   0.6232,
#   0.751,
#   0.691,
#   0.8022,
#   0.7628,
#   0.91,
#   0.811],
#  'Specificity': [0.9841555555555556,
#   0.9794222222222222,
#   0.9806222222222222,
#   0.9444888888888889,
#   0.9633555555555555,
#   0.9569777777777778,
#   0.9783333333333334,
#   0.9857111111111111,
#   0.9770222222222222,
#   0.9828222222222223],
#  'F1-Score': [0.7996638302342682,
#   0.8584087844345982,
#   0.6707413695529145,
#   0.5871490484266063,
#   0.721837754709727,
#   0.6649985564430758,
#   0.8033246545163228,
#   0.8065982869831871,
#   0.8597883597883598,
#   0.8251933251933252],
#  'confusion_matrix': [[3806, 61, 262, 62, 53, 23, 11, 19, 126, 96],
#   [128, 4456, 44, 27, 32, 30, 51, 24, 96, 494],
#   [130, 13, 2963, 153, 189, 129, 132, 80, 32, 14],
#   [128, 50, 441, 3116, 278, 829, 371, 254, 64, 83],
#   [101, 23, 430, 269, 3755, 211, 209, 348, 24, 34],
#   [46, 16, 346, 829, 201, 3455, 135, 317, 10, 36],
#   [46, 43, 258, 265, 169, 112, 4011, 29, 23, 30],
#   [31, 7, 105, 103, 206, 127, 13, 3814, 5, 46],
#   [422, 134, 88, 102, 77, 32, 43, 24, 4550, 112],
#   [162, 197, 63, 74, 40, 52, 24, 91, 70, 4055]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.951924}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.951924
# Mean Classification Error 0.048075999999999994
# Mean Precision 0.7648472314230204
# Mean Recall 0.75962
# Mean Specificity 0.9732911111111111
# Mean F1-Score 0.7597703970282386

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'lenet_base',
#  'time': '2022-10-13 20:26:10.091956',
#  'type': 'test',
#  'Accuracy': [0.9441,
#   0.949,
#   0.9182,
#   0.8855,
#   0.9192,
#   0.9069,
#   0.9449,
#   0.9454,
#   0.9468,
#   0.939],
#  'Classification Error': [0.0559,
#   0.051,
#   0.0818,
#   0.1145,
#   0.0808,
#   0.0931,
#   0.0551,
#   0.0546,
#   0.0532,
#   0.061],
#  'TP': [672, 772, 461, 510, 623, 574, 741, 666, 801, 675],
#  'FP': [231, 282, 279, 655, 431, 505, 292, 212, 333, 285],
#  'TN': [8769, 8718, 8721, 8345, 8569, 8495, 8708, 8788, 8667, 8715],
#  'FN': [328, 228, 539, 490, 377, 426, 259, 334, 199, 325],
#  'Precision': [0.7441860465116279,
#   0.7324478178368121,
#   0.6229729729729729,
#   0.43776824034334766,
#   0.5910815939278937,
#   0.5319740500463392,
#   0.7173281703775412,
#   0.7585421412300684,
#   0.7063492063492064,
#   0.703125],
#  'Recall': [0.672,
#   0.772,
#   0.461,
#   0.51,
#   0.623,
#   0.574,
#   0.741,
#   0.666,
#   0.801,
#   0.675],
#  'Specificity': [0.9743333333333334,
#   0.9686666666666667,
#   0.969,
#   0.9272222222222222,
#   0.9521111111111111,
#   0.9438888888888889,
#   0.9675555555555555,
#   0.9764444444444444,
#   0.963,
#   0.9683333333333334],
#  'F1-Score': [0.7062532842879663,
#   0.7517039922103214,
#   0.5298850574712644,
#   0.47113163972286376,
#   0.6066212268743915,
#   0.5521885521885521,
#   0.7289719626168224,
#   0.70926517571885,
#   0.7507029053420806,
#   0.6887755102040817],
#  'confusion_matrix': [[672, 26, 75, 14, 16, 10, 5, 7, 49, 29],
#   [32, 772, 15, 16, 13, 4, 10, 7, 41, 144],
#   [37, 8, 461, 57, 58, 50, 25, 27, 10, 7],
#   [30, 20, 101, 510, 75, 209, 94, 72, 24, 30],
#   [31, 9, 106, 66, 623, 51, 60, 82, 15, 11],
#   [9, 6, 104, 190, 46, 574, 43, 86, 8, 13],
#   [17, 12, 77, 64, 67, 29, 741, 8, 8, 10],
#   [8, 4, 26, 31, 68, 46, 4, 666, 5, 20],
#   [122, 48, 20, 26, 25, 14, 8, 9, 801, 61],
#   [42, 95, 15, 26, 9, 13, 10, 36, 39, 675]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.9299}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.9299
# Mean Classification Error 0.07010000000000001
# Mean Precision 0.654577523959581
# Mean Recall 0.6495
# Mean Specificity 0.9610555555555556
# Mean F1-Score 0.6495499306637195
