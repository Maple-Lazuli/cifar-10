# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
results_dir ="../results"
report = "lenet_base/"
full_dir = os.path.join(results_dir, report)
training_performance = os.path.join(full_dir, "training.json")
training_eval = os.path.join(full_dir, "train_evaluation.json")
test_eval = os.path.join(full_dir, "test_evaluation.json")

# %%
with open(training_performance, "r") as file_in:
    training_performance = json.load(file_in)
    
with open(training_eval, "r") as file_in:
    training_eval = json.load(file_in)
    
with open(test_eval, "r") as file_in:
    test_eval = json.load(file_in)

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1, = ax.plot(training_performance['train_loss'], label='Train Loss')
line2, = ax.plot(training_performance['val_loss'], label='Validation Loss')
ax.legend(handles=[line1, line2])
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.legend(handles=[line1, line2])
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch');

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
line1 = ax.imshow(np.array(training_performance['all_step_loss']), cmap='Blues')
ax.set_title(f"Loss During Training for {training_performance['name']}")
ax.set_ylabel('Epoch')
ax.set_xlabel('Step');

# %% [markdown]
# # Training Set Metrics

# %%
training_eval
# Out:
# {'name': 'lenet_base',
#  'time': '2022-10-13 20:00:26.537862',
#  'type': 'train',
#  'Accuracy': [0.94248,
#   0.95572,
#   0.91302,
#   0.90218,
#   0.92628,
#   0.92692,
#   0.95192,
#   0.94506,
#   0.96138,
#   0.95276],
#  'Classification Error': [0.05752,
#   0.04428,
#   0.08698,
#   0.09782,
#   0.07372,
#   0.07308,
#   0.04808,
#   0.05494,
#   0.03862,
#   0.04724],
#  'TP': [3988, 4241, 3052, 2670, 3177, 2394, 3334, 3947, 3951, 3689],
#  'FP': [1864, 1455, 2401, 2561, 1863, 1048, 738, 1694, 882, 1051],
#  'TN': [43136, 43545, 42599, 42439, 43137, 43952, 44262, 43306, 44118, 43949],
#  'FN': [1012, 759, 1948, 2330, 1823, 2606, 1666, 1053, 1049, 1311],
#  'Precision': [0.6814764183185236,
#   0.7445575842696629,
#   0.5596919127086007,
#   0.5104186580003823,
#   0.6303571428571428,
#   0.6955258570598489,
#   0.818762278978389,
#   0.6996986349937955,
#   0.8175046554934823,
#   0.7782700421940928],
#  'Recall': [0.7976,
#   0.8482,
#   0.6104,
#   0.534,
#   0.6354,
#   0.4788,
#   0.6668,
#   0.7894,
#   0.7902,
#   0.7378],
#  'Specificity': [0.9585777777777778,
#   0.9676666666666667,
#   0.9466444444444444,
#   0.9430888888888889,
#   0.9586,
#   0.9767111111111111,
#   0.9836,
#   0.9623555555555555,
#   0.9804,
#   0.9766444444444444],
#  'F1-Score': [0.7349797272392186,
#   0.7930067314884068,
#   0.5839471921936286,
#   0.5219431140650962,
#   0.6328685258964143,
#   0.5671641791044776,
#   0.7350088183421516,
#   0.7418475707170378,
#   0.8036204617105666,
#   0.7574948665297742],
#  'confusion_matrix': [[3988, 160, 424, 162, 180, 90, 57, 70, 503, 218],
#   [138, 4241, 78, 97, 45, 71, 132, 38, 208, 648],
#   [210, 24, 3052, 490, 583, 409, 415, 168, 62, 40],
#   [63, 32, 339, 2670, 273, 1138, 375, 214, 62, 65],
#   [82, 19, 440, 298, 3177, 252, 415, 293, 31, 33],
#   [27, 7, 165, 514, 95, 2394, 66, 139, 14, 21],
#   [11, 15, 152, 265, 108, 113, 3334, 24, 17, 33],
#   [83, 39, 201, 303, 453, 425, 64, 3947, 26, 100],
#   [249, 150, 85, 90, 45, 42, 48, 20, 3951, 153],
#   [149, 313, 64, 111, 41, 66, 94, 87, 126, 3689]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.937772}

# %%
print(f"Mean Accuracy {np.mean(training_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(training_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(training_eval['Precision'])}")
print(f"Mean Recall {np.mean(training_eval['Recall'])}")
print(f"Mean Specificity {np.mean(training_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(training_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.937772
# Mean Classification Error 0.06222799999999999
# Mean Precision 0.6936263184873921
# Mean Recall 0.68886
# Mean Specificity 0.9654288888888887
# Mean F1-Score 0.6871881187286772

# %% [markdown]
# # Validation Set Metrics

# %%
test_eval
# Out:
# {'name': 'lenet_base',
#  'time': '2022-10-13 20:00:27.372311',
#  'type': 'test',
#  'Accuracy': [0.9295,
#   0.9466,
#   0.9,
#   0.8875,
#   0.9087,
#   0.9121,
#   0.9436,
#   0.9317,
#   0.9508,
#   0.9387],
#  'Classification Error': [0.0705,
#   0.0534,
#   0.1,
#   0.1125,
#   0.0913,
#   0.0879,
#   0.0564,
#   0.0683,
#   0.0492,
#   0.0613],
#  'TP': [761, 789, 543, 428, 541, 426, 635, 725, 726, 672],
#  'FP': [466, 323, 543, 553, 454, 305, 199, 408, 218, 285],
#  'TN': [8534, 8677, 8457, 8447, 8546, 8695, 8801, 8592, 8782, 8715],
#  'FN': [239, 211, 457, 572, 459, 574, 365, 275, 274, 328],
#  'Precision': [0.6202118989405053,
#   0.7095323741007195,
#   0.5,
#   0.436289500509684,
#   0.5437185929648242,
#   0.5827633378932968,
#   0.7613908872901679,
#   0.6398940864960282,
#   0.7690677966101694,
#   0.7021943573667712],
#  'Recall': [0.761,
#   0.789,
#   0.543,
#   0.428,
#   0.541,
#   0.426,
#   0.635,
#   0.725,
#   0.726,
#   0.672],
#  'Specificity': [0.9482222222222222,
#   0.9641111111111111,
#   0.9396666666666667,
#   0.9385555555555556,
#   0.9495555555555556,
#   0.9661111111111111,
#   0.9778888888888889,
#   0.9546666666666667,
#   0.9757777777777777,
#   0.9683333333333334],
#  'F1-Score': [0.6834306241580602,
#   0.7471590909090909,
#   0.5206136145733461,
#   0.4321049974760222,
#   0.5423558897243108,
#   0.4922010398613518,
#   0.69247546346783,
#   0.6797937177684014,
#   0.7469135802469135,
#   0.686765457332652],
#  'confusion_matrix': [[761, 41, 108, 38, 37, 23, 16, 20, 124, 59],
#   [37, 789, 12, 30, 10, 9, 12, 16, 66, 131],
#   [44, 6, 543, 94, 146, 90, 97, 42, 13, 11],
#   [19, 9, 82, 428, 55, 236, 76, 47, 11, 18],
#   [16, 11, 108, 87, 541, 60, 83, 66, 10, 13],
#   [4, 2, 44, 140, 30, 426, 20, 50, 4, 11],
#   [13, 8, 31, 62, 38, 29, 635, 4, 3, 11],
#   [12, 5, 43, 70, 116, 101, 26, 725, 6, 29],
#   [53, 40, 18, 18, 15, 11, 14, 4, 726, 45],
#   [41, 89, 11, 33, 12, 15, 21, 26, 37, 672]],
#  'Classes': ['plane',
#   'car',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'Total Accuracy': 0.92492}

# %%
print(f"Mean Accuracy {np.mean(test_eval['Accuracy'])}")
print(f"Mean Classification Error {np.mean(test_eval['Classification Error'])}")
print(f"Mean Precision {np.mean(test_eval['Precision'])}")
print(f"Mean Recall {np.mean(test_eval['Recall'])}")
print(f"Mean Specificity {np.mean(test_eval['Specificity'])}")
print(f"Mean F1-Score {np.mean(test_eval['F1-Score'])}")
# Out:
# Mean Accuracy 0.92492
# Mean Classification Error 0.07508000000000001
# Mean Precision 0.6265062832172166
# Mean Recall 0.6245999999999999
# Mean Specificity 0.9582888888888889
# Mean F1-Score 0.6223813475517979
